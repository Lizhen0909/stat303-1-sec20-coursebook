# %% [raw]
# ---
# title: "Activity 4: Select, Transform, and Explain"
# author: "Your Name"
# format:
#   html:
#     embed-resources: true
#     toc: true
#     code-fold: false
# ---

# %% [markdown]
# # My Pandas Analysis
#
# Follow the [complete chapter activity instructions](https://lizhen0909.github.io/stat303-1-sec20-coursebook/pandas_fundamentals.html#practice-activity-select-transform-and-explain). Use the verified project environment and `stat303-pandas-fundamentals` as your working directory.

# %%
from pathlib import Path
import pandas as pd
print('Working folder:', Path.cwd().name)
movie_path = Path('data') / 'movie_ratings.csv'
print('Movie file found:', movie_path.is_file())

# %% [markdown]
# ## A. Labels, Positions, and Shapes
#
# Run the table, then record your predictions before running the selections specified in the chapter.

# %%
screenings = pd.DataFrame(
    {'Title': ['Cedar', 'Harbor', 'Orbit', 'Meadow', 'Ember'],
     'Rating': [7.2, 8.1, 6.5, 8.1, 7.8],
     'Tickets': [120, 80, 150, 90, 110]},
    index=[104, 101, 107, 103, 109],
)
screenings

# %% [markdown]
# Write your predictions here.

# %%
# Add the selections and shape checks requested in A.

# %% [markdown]
# Explain the observed selections and shapes here.

# %% [markdown]
# ## B. Filter and Sort Movie Records
#
# Follow section B in the chapter. Add code cells as needed.

# %%
# Add your code for B here.

# %% [markdown]
# Record your interpretation here.

# %% [markdown]
# ## C. Create a Variable and Keep an Update
#
# Follow section C in the chapter. Add code cells as needed.

# %%
# Add your code for C here.

# %% [markdown]
# Record your interpretation here.

# %% [markdown]
# ## D. Summarize and Explain Your Denominator
#
# Follow section D in the chapter. Add code cells as needed.

# %%
# Add your code for D here.

# %% [markdown]
# Record your interpretation here.

# %% [markdown]
# ## Completion Note
#
# Record your fresh-run, save, and HTML inspection checks.
