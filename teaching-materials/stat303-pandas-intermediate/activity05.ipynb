# %% [raw]
# ---
# title: "Activity 5: Calculate, Align, and Explain"
# author: "Your Name"
# format:
#   html:
#     code-fold: false
#     toc: true
#     toc-depth: 2
# jupyter: python3
# ---

# %% [markdown]
# # Calculate, Align, and Explain
#
# Follow the [complete chapter instructions](https://lizhen0909.github.io/stat303-1-sec20-coursebook/pandas_intermediate.html#practice-activity-calculate-align-and-explain).
# Add your predictions, code, outputs, and explanations below.
#
# Run the setup cell first, then the supplied-inputs cell. Every table the activity needs is
# created in Python, so this activity needs no data file.

# %%
from pathlib import Path
import pandas as pd

print('Working folder:', Path.cwd().name)
print('Kit folder confirmed:', Path('README.md').is_file())

# %% [markdown]
# ## Supplied Inputs
#
# Run this cell unchanged. All values are invented for practice.

# %%
sales = pd.DataFrame({
    'Product': ['Notebook', 'Pen', 'Folder', 'Mug'],
    'Department': ['Office', 'Office', 'Office', 'Gifts'],
    'Units': [12, 30, 20, 5],
    'Price': [8.0, 2.0, 4.0, 6.0],
    'Unit_Cost': [5.0, 0.8, 2.0, 7.0],
}, index=['P10', 'P20', 'P30', 'P40'])

quarter_sales = pd.DataFrame({
    'Q1': [100, 200, 150], 'Q2': [120, 180, 160],
}, index=['P10', 'P20', 'P30'])
adjustments = pd.DataFrame({
    'Q2': [10, -5, 20], 'Q3': [30, 40, 50],
}, index=['P30', 'P10', 'P40'])

department_labels = {'Office': 'Office Supplies'}
campaigns = pd.DataFrame({
    'Advertising': [600, 1400, 950, 700, 1250, 1050],
    'Revenue': [16000, 30500, 22000, 18500, 27500, 24000],
})
sales

# %% [markdown]
# ## A. Calculate with Explicit Inputs
#
# Write your predictions or explanations here.

# %%
# Your work here

# %% [markdown]
# ## B. Predict and Check Alignment
#
# Write your predictions or explanations here.

# %%
# Your work here

# %% [markdown]
# ## C. Recode and Apply a Rule
#
# Write your predictions or explanations here.

# %%
# Your work here

# %% [markdown]
# ## D. Interpret a Relationship
#
# Write your predictions or explanations here.

# %%
# Your work here

# %% [markdown]
# ## Completion Note
#
# Describe your checks after restarting and running all cells.
